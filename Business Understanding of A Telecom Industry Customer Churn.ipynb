# %% [markdown]
# Here we have analyzed the dataset of an European Telecom Company.
#
# This Telecom's Chrun Dataset, consists of cleaned customer activity data(features), along with a churn label specifying whether
# a customer cancelled the subscription
#
# We explore and analyze the data to discover key factors responsible for customer churn and come up with ways/recommendations to
# ensure customer retention.

# %% [markdown]
# # Business Understanding Of A Telecom Industry Customer Churn:

# %% [markdown]
# Customer churn is a big problem in any industry and one of the most important concerns for the Telecom industry.
#
# The effect on the revenues of the companies, because of this customer churns is huge, especially in the telecom field, that's
# why these companies are seeking to develop a predictive potential customer churn.
#
# In this highly competitive market, the telecommunication industry experiences an average of 15-25% annual churn rate, and it
# costs 5-10 times more to acquire a new customer than to retain an existing one, that's why customer retention has now become
# even more important than customer acquistion.
#
# Therefore, finding those factors that increase customer churn is important to take necessary actions to reduce this churn.
#
# The main goal of this project is to develop an understanding of the cause of customer churn which assists telecom operators to
# predict customer who are most likely subject to churn, and what to do to retain the most valuable customer.
#
# We will find how we can maximize the profit by retaining customer, and, how we can reduce the churn rate by identifying the issues

# %%
# importing the required linraries

import pandas as pd               # To import pandas library
import seaborn as sns             # To import the seaborn library
import matplotlib.pyplot as plt   # To import the matplotlip library
# %matplotlib inline                
                                  # it is used to show plots/graphs without writing plt.show()

# %%
# importing the dataset

data = pd.read_csv(r"G:\Form Essentials\Data Gyan\Portfolio Project\Python Projects/Telecom Churn Dataset.csv")

# %% [markdown]
# # Exploring the Dataset

# %%
data # to have look at our dataset; it will show top 5 and bottom 5 rows and about 20 columns
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 2661    SC              79        415                 No              No
# 2662    AZ             192        415                 No             Yes
# 2663    WV              68        415                 No              No
# 2664    RI              28        510                 No              No
# 2665    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
data.head() # to show top 5 records of the dataset
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
data.tail() # to show bottom 5 records of the dataset
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 2661    SC              79        415                 No              No
# 2662    AZ             192        415                 No             Yes
# 2663    WV              68        415                 No              No
# 2664    RI              28        510                 No              No
# 2665    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 2661                      0              134.7               98
# 2662                     36              156.2               77
# 2663                      0              231.1               57
# 2664                      0              180.8              109
# 2665                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
data.info() # to show the basic information about the dataset. It shows indexes, columns count, each column name with its non-null
# values count & data-type, and memory of dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2666 entries, 0 to 2665
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   2666 non-null   object
#  1   Account length          2666 non-null   int64
#  2   Area code               2666 non-null   int64
#  3   International plan      2666 non-null   object
#  4   Voice mail plan         2666 non-null   object
#  5   Number vmail messages   2666 non-null   int64
#  6   Total day minutes       2666 non-null   float64
#  7   Total day calls         2666 non-null   int64
#  8   Total day charge        2666 non-null   float64
#  9   Total eve minutes       2666 non-null   float64
#  10  Total eve calls         2666 non-null   int64
#  11  Total eve charge        2666 non-null   float64
#  12  Total night minutes     2666 non-null   float64
#  13  Total night calls       2666 non-null   int64
# ...

# %%
data.shape # to show the number of rows and columns in the dataframe
# Out:
# (2666, 20)

# %%
data.nunique() # to show the number of unique values in each column
# Out:
# State                       51
# Account length             205
# Area code                    3
# International plan           2
# Voice mail plan              2
# Number vmail messages       42
# Total day minutes         1489
# Total day calls            115
# Total day charge          1489
# Total eve minutes         1442
# Total eve calls            120
# Total eve charge          1301
# Total night minutes       1444
# Total night calls          118
# Total night charge         885
# Total intl minutes         158
# Total intl calls            21
# Total intl charge          158
# Customer service calls      10
# Churn                        2
# dtype: int64

# %%
data.columns # to show all the column names in the dataframe
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
data.dtypes # to show the data-type of each column
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls             int64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls             int64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls           int64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls      int64
# Churn                        bool
# dtype: object

# %%
data.describe()

# it gives the summary statistics of all numeric columns. It checks extreme outliers and large deviations etc.
# it shows the count of non-null values in each column, and mean,std,minimum,maximum, 25th, 50th, 75th percentile value
#of each column
# 'Percentile' means - how many of the values are less than the given percentile
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     2666.000000  2666.000000            2666.000000         2666.00000
# mean       100.620405   437.438860               8.021755          179.48162
# std         39.563974    42.521018              13.612277           54.21035
# min          1.000000   408.000000               0.000000            0.00000
# 25%         73.000000   408.000000               0.000000          143.40000
# 50%        100.000000   415.000000               0.000000          179.95000
# 75%        127.000000   510.000000              19.000000          215.90000
# max        243.000000   510.000000              50.000000          350.80000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      2666.000000       2666.000000        2666.000000      2666.000000
# mean        100.310203         30.512404         200.386159       100.023631
# ...

# %%
data.describe(include='object')  # it gives the summary of all categorical columns
# it shows the count of non-null and unique values of each column, top value with its occurence in each column
# Out:
#        State International plan Voice mail plan
# count   2666               2666            2666
# unique    51                  2               2
# top       WV                 No              No
# freq      88               2396            1933

# %% [markdown]
# # Checking Missing and Duplicate Values

# %%
data.head(2) # to show the top 2 records of the dataframe
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3                2.7
# ...

# %%
data.isna().sum() # to show the count of missing (null) values in each column
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
data.isnull().sum()  # Alternatively, to show the count of missing (null) values in each column
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
data.notnull().sum() # to show the count of non-null values in each column
# Out:
# State                     2666
# Account length            2666
# Area code                 2666
# International plan        2666
# Voice mail plan           2666
# Number vmail messages     2666
# Total day minutes         2666
# Total day calls           2666
# Total day charge          2666
# Total eve minutes         2666
# Total eve calls           2666
# Total eve charge          2666
# Total night minutes       2666
# Total night calls         2666
# Total night charge        2666
# Total intl minutes        2666
# Total intl calls          2666
# Total intl charge         2666
# Customer service calls    2666
# Churn                     2666
# dtype: int64

# %%
data.notna().sum()  # Alternatively, to show the count of non-null values in each column
# Out:
# State                     2666
# Account length            2666
# Area code                 2666
# International plan        2666
# Voice mail plan           2666
# Number vmail messages     2666
# Total day minutes         2666
# Total day calls           2666
# Total day charge          2666
# Total eve minutes         2666
# Total eve calls           2666
# Total eve charge          2666
# Total night minutes       2666
# Total night calls         2666
# Total night charge        2666
# Total intl minutes        2666
# Total intl calls          2666
# Total intl charge         2666
# Customer service calls    2666
# Churn                     2666
# dtype: int64

# %%
data[data.duplicated()]  # to show the duplicate records present in the dataframe
# Out:
# Empty DataFrame
# Columns: [State, Account length, Area code, International plan, Voice mail plan, Number vmail messages, Total day minutes, Total day calls, Total day charge, Total eve minutes, Total eve calls, Total eve charge, Total night minutes, Total night calls, Total night charge, Total intl minutes, Total intl calls, Total intl charge, Customer service calls, Churn]
# Index: []

# %%
# in this dataframe, no duplicate records present

# %%
data = data.drop_duplicates()  # to drop all the duplicate records from the dataframe and saving the updated dataframe

# %%
data  # to have a look at the dataframe
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 2661    SC              79        415                 No              No
# 2662    AZ             192        415                 No             Yes
# 2663    WV              68        415                 No              No
# 2664    RI              28        510                 No              No
# 2665    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %% [markdown]
# # 1. Analyzing the 'Churn' Variable

# %%
data.head() # to show top 5 records of the dataframe
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
data['Churn'].unique()  # to show the unique values present in the column 'Churn'
                        # it shows the output in the form of 1-D array
# Out:
# array([False,  True])

# %%
A= data['Churn'].value_counts()  # to show the count of the unique values of the column 'Churn' and saving the result in 
print(A)                         # variable 'A' and printing the variable 'A'
# Out:
# False    2278
# True      388
# Name: Churn, dtype: int64

# %%
str(388/2666*100) + "%"  # to check the percentage of True(Churned Customers) from the dataset...
                         #... and sharing the result in string format, after adding % symbol at the end
# Out:
# '14.553638409602401%'

# %%
type(A)  # to check the datatype
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Doughnut Chart

# %%
# Creating a Doughnut Chart for Churn vs Non-Churn Customers

plt.pie(A, labels=['Not Churned','Churned'], colors=['orange','lime'], startangle=50, shadow= True, radius=2,
        explode=(0,0.2), autopct='%1.2f%%', pctdistance=0.75);

circle = plt.Circle((0,0), 1, color='white')  
c= plt.gcf()

c.gca().add_artist(circle)
plt.title("Churned vs Non-Churned Customers (DSL)")
plt.show()

# %% [markdown]
# # Countplot

# %%
# Countplot for Churn vs Non-Churn Customers

sns.countplot(x='Churn', data=data)

# Drawing a countplot for the column 'Churn' from the dataset using seaborn library
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %% [markdown]
# Outcome -
#
# after analyzing the churn column, we notice that almost 15% customers have churned. Now, we will analyze other
# columns to find out the possible reasons for the churn

# %% [markdown]
# # 2. Analyzing the State Column

# %%
data.head(2)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3                2.7
# ...

# %%
data.State.nunique()
# Out:
# 51

# %%
data.State.unique()  # to show all the unique values of the 'State' Column
                     # it shows the output in the form of 1-D array
# Out:
# array(['KS', 'OH', 'NJ', 'OK', 'AL', 'MA', 'MO', 'WV', 'RI', 'IA', 'MT',
#        'ID', 'VT', 'VA', 'TX', 'FL', 'CO', 'AZ', 'NE', 'WY', 'IL', 'NH',
#        'LA', 'GA', 'AK', 'MD', 'AR', 'WI', 'OR', 'DE', 'IN', 'UT', 'CA',
#        'SD', 'NC', 'WA', 'MN', 'NM', 'NV', 'DC', 'NY', 'KY', 'ME', 'MS',
#        'MI', 'SC', 'TN', 'PA', 'HI', 'ND', 'CT'], dtype=object)

# %%
data.State.value_counts()  # to show the occurence/count of all the unique values of the column 'State'

# By default, it shows the result in descending order
# To see the result in ascending order, we can write data.State.value_counts(ascending=True)
# Out:
# WV    88
# MN    70
# NY    68
# VA    67
# AL    66
# OH    66
# WY    66
# OR    62
# NV    61
# WI    61
# MD    60
# UT    60
# CO    59
# CT    59
# MI    58
# VT    57
# ID    56
# NC    56
# TX    55
# FL    54
# IN    54
# MT    53
# OK    52
# MA    52
# KS    52
# MO    51
# DE    51
# NJ    50
# SC    49
# SD    49
# ME    49
# GA    49
# RI    48
# MS    48
# WA    48
# AR    47
# IL    45
# DC    45
# AZ    45
# NE    45
# HI    44
# NM    44
# ND    44
# AK    43
# KY    43
# NH    43
# TN    41
# IA    38
# PA    36
# LA    35
# CA    24
# Name: State, dtype: int64

# %% [markdown]
# # Countplot

# %%
plt.figure(figsize=(20, 7))   # Setting the size of the figure as 20X7 using Matplotlib library

sns.countplot(x='State', data=data)  # Drawing the Countplot for the column 'State' 

plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.xlabel('States', fontsize=20, color='Red')  
plt.ylabel('Count', fontsize=20, color='Green')  

plt.show()

# %%
data.head(2)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3                2.7
# ...

# %% [markdown]
# # groupby

# %%
a = data.groupby('State')['Churn'].mean()*100

a.sort_values()

# Here we will consider two columns while using groupby()
# Used groupby on ('State') column... and showing the mean of values of ['Churn'] Column wrt to each state...
#... and multiplying the result by 100
# By default, it will consider 'True' values from ['Churn'] column to calculate the mean...
#... bcz the data type of column 'Churn' is boolean type
# Out:
# State
# HI     4.545455
# VA     5.970149
# RI     6.250000
# WI     6.557377
# AZ     6.666667
# AK     6.976744
# IA     7.894737
# WV     7.954545
# LA     8.571429
# NE     8.888889
# IL     8.888889
# ID     8.928571
# ND     9.090909
# NM     9.090909
# MO     9.803922
# VT    10.526316
# AL    10.606061
# DC    11.111111
# IN    11.111111
# OR    11.290323
# CO    11.864407
# WY    12.121212
# TN    12.195122
# SD    12.244898
# FL    12.962963
# UT    13.333333
# OK    13.461538
# KY    13.953488
# OH    15.151515
# MA    15.384615
# DE    15.686275
# NC    16.071429
# GA    16.326531
# NY    17.647059
# MN    18.571429
# CT    18.644068
# MT    18.867925
# KS    19.230769
# CA    20.833333
# WA    20.833333
# NH    20.930233
# NV    21.311475
# PA    22.222222
# MI    22.413793
# SC    22.448980
# ME    22.448980
# MS    22.916667
# MD    23.333333
# AR    23.404255
# NJ    28.000000
# TX    29.090909
# Name: Churn, dtype: float64

# %% [markdown]
# # Line Chart

# %%
# Drawing a Line Chart showing State-Wise Churn State

X = data.State.unique()  #considering all unique values o fstate column, and sharing the output in variable X 
Y = data.groupby("State")['Churn'].mean()  # Using groupby on State Column, and calculating the mean of churn...
# ... values against each state,a nd saving the output in variable Y

sns.set(style="darkgrid")  # Using seaborn library, setting the background of the figure as "whitegrid"

plt.rcParams['figure.figsize'] = (20,7)  # Using rcParams from Matplotlib library...
# ... setting the size of figure as 20X7

plt.rcParams['lines.linestyle'] = '-'  # Using rcParams from matplotlib library setting the line style to '-'

plt.plot(X,Y,color='black',marker='*',markersize='10')  # Plotting a line chart with Xand Y
#... showing the States on X axis & Churn rate on Y axis, setting color of line as black, marker as '*' and its size as '10'

plt.title('State Churn Graph', fontsize =25)  # setting the title of chart, with fontsize as 25
plt.xlabel('States',fontsize = 20)  # setting the label of x-axis, with fontsize = 20
plt.ylabel('Churn Rate', fontsize = 20)  # setting the label of y-axis, with fontsize = 20

#rcParams - run command parameters
#matplotlib.rcParams contains some properties in matplotlibrc file, which we can use to control the defaults of almost every 
#... property in the Matplotlib: figue size and DPI, line width, color and style, axes, axis...
#... and grid properties, text and font properties and so on. In order to use matplotlib
# Out:
# Text(0, 0.5, 'Churn Rate')

# %%
#x = data.State
#x = data.groupby("State")['Churn'].mean().sort_values(ascending=False).head(5);
#y = data.groupby("State")['Churn'].mean().sort_values(ascending=False)

#plt.bar(x,y)

data.groupby("State")['Churn'].mean().sort_values(ascending=False).head(5)*100
# Out:
# State
# TX    29.090909
# NJ    28.000000
# AR    23.404255
# MD    23.333333
# MS    22.916667
# Name: Churn, dtype: float64

# %%
data.head()  # to show top 5 records of the dataset
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %% [markdown]
# # crosstab()

# %%
# Calculating State vs Churn Percentage

c = pd.crosstab(data.State, data.Churn, margins=True)
# Using crosstab from pandas library to compute simple cross-tabulation o ftwo columns i.e., State & Churn and saving the output
# in variable c

c['Percentage_Churn'] = c[True]/(c['All'])*100  # Creating a new column Percentage_Churn, which shows the percentage of churn
#... customers in each state
print(c.head())  # printing top 5 records of the result
print(type(c))  # printing type of 'c'
# Out:
# Churn  False  True  All  Percentage_Churn
# State
# AK        40     3   43          6.976744
# AL        59     7   66         10.606061
# AR        36    11   47         23.404255
# AZ        42     3   45          6.666667
# CA        19     5   24         20.833333
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# # info()

# %%
c.info()  # To show te basic information of dataframe 'c'
# It shows indexes, columns counts, each column name with its non-null values count & data-type and, memory of Dataframe
# Now, in this dataframe 'c', we have 4 columns'False, True, All, PErcentage_Churn' each having 52 non-null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52 entries, AK to All
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   False             52 non-null     int64
#  1   True              52 non-null     int64
#  2   All               52 non-null     int64
#  3   Percentage_Churn  52 non-null     float64
# dtypes: float64(1), int64(3)
# memory usage: 2.0+ KB

# %% [markdown]
# # sort_values()

# %%
c.sort_values(by='Percentage_Churn', ascending=False).head()

# sorting the records of dataframe 'c' wrt the column'Percentage_Churn' in descending order and showing top 5 records
# Out:
# Churn  False  True  All  Percentage_Churn
# State
# TX        39    16   55         29.090909
# NJ        36    14   50         28.000000
# AR        36    11   47         23.404255
# MD        46    14   60         23.333333
# MS        37    11   48         22.916667

# %% [markdown]
# # 3. Analyzing the 'Area Code' Column

# %%
data.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
data['Area code'].nunique()
# Out:
# 3

# %%
data['Area code'].unique()
# Out:
# array([415, 408, 510], dtype=int64)

# %%
data['Area code'].value_counts()  # to show the count of all unique values of teh column 'Area code'
# Out:
# 415    1318
# 510     679
# 408     669
# Name: Area code, dtype: int64

# %%
data.groupby('Area code')['Churn'].mean()*100

# here we are considering two columns while using groupby()
# used groupby on Area code column and showing the mean value of churn column wrt each area code
# Out:
# Area code
# 408    14.050822
# 415    14.795144
# 510    14.580265
# Name: Churn, dtype: float64

# %%
# Calculating Area code vs Churn Percentage

d = pd.crosstab(data['Area code'], data.Churn, margins=True)
# Using crosstab from pandas library to compute simple cross-tabulation of two columns i.e., Area code & Churn and saving the 
# output in variable d

d['Percentage_Churn'] = d[True]/(c['All'])*100  # Creating a new column Percentage_Churn, which shows the percentage of churn
#... customers in each Area code
print(d.head())  # printing top 5 records of the result
print(type(d))  # printing type of 'd'
# Out:
# Churn      False  True   All  Percentage_Churn
# Area code
# 408          575    94   669               NaN
# 415         1123   195  1318               NaN
# 510          580    99   679               NaN
# All         2278   388  2666         14.553638
# <class 'pandas.core.frame.DataFrame'>

# %%
# Drawing a bar graph to show Area code wise Churn

plt.figure(figsize=(14,5))
# setting the size of the figure as 14X5, using matplotlib library

sns.countplot(x='Area code', hue='Churn', data=data);
# Drawing a countplot for the column 'Area code' from the dataset using seaborn library...
#... selecting the churn column for hue
# 'hue=churn' represents that we want to use column 'Churn' for color encoding
# i.e. color the bars for churn and not churn differently
# Blue color representing False(Not Churn) and Orange color reprsenting True(Churn) for each Area code separately

# %% [markdown]
# # 4. Analyzing the 'Account Length' Column

# %%
data.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
data['Account length'].nunique()  # to show the total number of unique values present in the column 'Account length'
# Out:
# 205

# %% [markdown]
# # creating dataframes

# %%
# Creating two different dataframes - one for churned customers and other for non-churned customers

churn_data = data[data['Churn'] == True]  # churned customers

not_churn_data = data[data['Churn'] == False]  # not-churned customers

# %%
churn_data.head(2)
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 18    CO              77        408                 No              No
# 28    AZ              12        408                 No              No
#
#     Number vmail messages  Total day minutes  Total day calls  \
# 18                      0               62.4               89
# 28                      0              249.6              118
#
#     Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 18             10.61              169.9              121             14.44
# 28             42.43              252.4              119             21.45
#
#     Total night minutes  Total night calls  Total night charge  \
# 18                209.6                 64                9.43
# 28                280.2                 90               12.61
#
#     Total intl minutes  Total intl calls  Total intl charge  \
# 18                 5.7                 6               1.54
# ...

# %%
not_churn_data.head(2)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3                2.7
# ...

# %%
churn_data.info()  # to show the basic information of the dataframe "churn_data"
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 388 entries, 18 to 2658
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   388 non-null    object
#  1   Account length          388 non-null    int64
#  2   Area code               388 non-null    int64
#  3   International plan      388 non-null    object
#  4   Voice mail plan         388 non-null    object
#  5   Number vmail messages   388 non-null    int64
#  6   Total day minutes       388 non-null    float64
#  7   Total day calls         388 non-null    int64
#  8   Total day charge        388 non-null    float64
#  9   Total eve minutes       388 non-null    float64
#  10  Total eve calls         388 non-null    int64
#  11  Total eve charge        388 non-null    float64
#  12  Total night minutes     388 non-null    float64
#  13  Total night calls       388 non-null    int64
# ...

# %%
not_churn_data.info() # to show the basic information of the dataframe "not_churn_data"
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2278 entries, 0 to 2665
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   2278 non-null   object
#  1   Account length          2278 non-null   int64
#  2   Area code               2278 non-null   int64
#  3   International plan      2278 non-null   object
#  4   Voice mail plan         2278 non-null   object
#  5   Number vmail messages   2278 non-null   int64
#  6   Total day minutes       2278 non-null   float64
#  7   Total day calls         2278 non-null   int64
#  8   Total day charge        2278 non-null   float64
#  9   Total eve minutes       2278 non-null   float64
#  10  Total eve calls         2278 non-null   int64
#  11  Total eve charge        2278 non-null   float64
#  12  Total night minutes     2278 non-null   float64
#  13  Total night calls       2278 non-null   int64
# ...

# %%
data.shape  # to show the number of rows and columns in the dataframe
# Out:
# (2666, 20)

# %% [markdown]
# # Distribution Plot

# %%
# Creating a distribution plot for Account Length column

sns.displot(data['Account length'], color='orange')
plt.xlabel('Account Length', fontsize=15)
plt.ylabel('Density', fontsize=15)
plt.show()
# The distplot shows the histogram with a line on it. It represents the distribution of a variable against the desity of 
# distribution

# Here, we are usng seaborn library, we are plotting a distribution plot for the column 'account length'...
#... with orange color.

# %%
# Comparing Account Length of 'churned' and 'not churned customers, using histplot

sns.histplot(data['Account length'], color='grey', label="All")
# Using Seaborn Library, we are plotting a histogram for the column account length from the original dataframe...
# ...with 'grey' color and setting the label as 'ALL

sns.histplot(churn_data['Account length'], color='red', label='Churned', kde=True)
# Using Seaborn Library, we are plotting a histogram for the column account length from "churn data"...
# ...dataframe with 'red' color and setting the label as 'Churned'. We include KDE (Kernel Density Estimate) here.

sns.histplot(not_churn_data['Account length'], color='yellow', label='Not Churned', kde=True)
# Using Seaborn Library, we are plotting a histogram for the column account length from the non-churn data"...
# ...dataframe with yellow color and setting the label as 'Not Churned'. We include KDE (Kernel Density Estimate) here.

plt.xlabel("Account Length", fontsize=15)
# Using matplotlib, we set the label of the x-axis as "Account Length" with a fontsize of 15.

plt.ylabel("Density", fontsize=15)
# Using matplotlib, we set the label of the y-axis as "Density" with a fontsize of 15.

plt.rcParams['figure.figsize'] = (15, 7)
# Setting the size of the figure as 15x7 using matplotlib's rcParams.

plt.legend()
# Adding the legend to the plot to distinguish between 'Churned' and 'Not Churned'.

plt.show()  # To show the plot.

# %% [markdown]
# # 5. Analyzing the 'International Plan' Column

# %%
data.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
data['International plan'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data['International plan'].value_counts()
# Out:
# No     2396
# Yes     270
# Name: International plan, dtype: int64

# %% [markdown]
# # creating dataframe

# %%
# Creating dataframe for churned customers who were having international plan 
yes_int_plan = data[(data['International plan'] == 'Yes') & data['Churn'] == True] 
yes_int_plan

# Here, we have used filtering with '&' operator, to select records satisfying two conditions
#1. 'international plan' == yes
#2. 'Churn' == true

#it shows there are total 118 records satisfying these two conditions
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 35      MD             135        408                Yes             Yes
# 93      ME              36        510                Yes             Yes
# 120     VT             117        408                Yes              No
# 162     ME             131        510                Yes             Yes
# 176     FL              70        510                Yes              No
# ...    ...             ...        ...                ...             ...
# 2597    NC              77        408                Yes             Yes
# 2605    RI             138        510                Yes              No
# 2631    MI             119        510                Yes             Yes
# 2641    IL              71        510                Yes              No
# 2656    GA             122        510                Yes              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
# Creating dataframe for churned customers who were not having international plan 
no_int_plan = data[(data['International plan'] == 'No') & data['Churn'] == True] 
no_int_plan

# Here, we have used filtering with '&' operator, to select records satisfying two conditions
#1. 'international plan' == no
#2. 'Churn' == true

#it shows there are total 270 records satisfying these two conditions
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 18      CO              77        408                 No              No
# 28      AZ              12        408                 No              No
# 45      WY              87        415                 No              No
# 48      CO             121        408                 No             Yes
# 58      TX             150        510                 No              No
# ...    ...             ...        ...                ...             ...
# 2614    ID              82        415                 No              No
# 2624    AR              76        408                 No              No
# 2628    KS             170        415                 No             Yes
# 2657    MD              62        408                 No              No
# 2658    IN             117        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
# we noticed that customers were using international plan, and 118 churned out of them
# means a churned percentage of 43.7

118/270*100
# Out:
# 43.7037037037037

# %%
# we noticed that customers were not using international plan, and 270 churned out of them
# means a churned percentage of 11.2

270/2396*100
# Out:
# 11.268781302170282

# %% [markdown]
# # crosstab()

# %%
int_plan_data = pd.crosstab(data['International plan'], data['Churn'], margins=True)

int_plan_data
# Out:
# Churn               False  True   All
# International plan
# No                   2126   270  2396
# Yes                   152   118   270
# All                  2278   388  2666

# %% [markdown]
# # creating new column

# %%
# creating new column 'churn percent' to show the percentage of the customers who were using international plan

int_plan_data['churn percent'] = int_plan_data[True]/int_plan_data['All']*100
int_plan_data
# Out:
# Churn               False  True   All  churn percent
# International plan
# No                   2126   270  2396      11.268781
# Yes                   152   118   270      43.703704
# All                  2278   388  2666      14.553638

# %%
int_plan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, No to All
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   False          3 non-null      int64
#  1   True           3 non-null      int64
#  2   All            3 non-null      int64
#  3   churn percent  3 non-null      float64
# dtypes: float64(1), int64(3)
# memory usage: 120.0+ bytes

# %%
i = data['International plan'].value_counts()
i # to show the unique values of the column 'International plan', and saving in variable i
# Out:
# No     2396
# Yes     270
# Name: International plan, dtype: int64

# %% [markdown]
# # Doughnut Chart

# %%
# Creating a Donut Chart of customers count having 'International plan' and 'not having international plan

plt.pie(i, labels=["No", "Yes"], colors=['yellow', 'cyan'], startangle=50, shadow=True, radius=2, explode=(0,0.2), autopct='%1.2f%%', pctdistance=0.75);

circle = plt.Circle((0,0), 1, color="white")
c = plt.gcf()
                                         
c.gca().add_artist(circle)
plt.title("International Plan (DSL)")
plt.rcParams['figure.figsize'] = (2,5)
plt.show()
# Donut chart is a modified Pie chart, with an area from center cut out 
#1 First, drawing a pie plot, using Matplotlib Library
# The data is taken from the variable 'i'.... Labels are given as "No" & "Yes"...
# ...color is given to each label "yellow" & "cyan"... startangle means the angle for slicing, set as 50 25 plt.gcf() is used to get the current figure... and we are saving it in variable 'c'
#... shadow is True means it will drop some shadow of the chart... radius of the circle is set os 2... 20... explode is used to cut the slice out of the figure.
#... autopct is used to show the X on the chart upto required decimal points.....
# petdistance is given for distance of & from the center 21 #2 Second, using plt.Circle...we will create a circle and save it in the variable name 'circle... 24. putting (0,0) by default is radius of circle... and color of circle is "white"
# Third, we will add the 'circle at the center of pie chart... using gra().add_artist() 27 We have given the title to the chart using plt.title()
# Using rcParams from matplotlib Library, setting the size of the figure as 5x7 20 plt.show() To show the chart

# %% [markdown]
# # Countplot

# %%
plt.figure(figsize=(10, 4))
sns.countplot(x='International plan', hue='Churn', data=data)
plt.show

# Drawing a countplot for the column 'Internatinal plan' from the dataset using seaborn library, selecting the column
# Churn for hue
# hue=Churn represents that we want to use column "Churn" for color encoding 
# i.e. color the bars for Churn and Not-Churn differently
# Blue for False(Not-Churn) and Orange for True(Churn)
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # 6. Analyzing the 'Voice mail plan' Column

# %%
data.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %% [markdown]
# # countplot()

# %%
plt.figure(figsize=(10, 5))
sns.countplot(x = 'Voice mail plan', hue='Churn', data=data, color='green')
plt.show()

# Drawing a countplot for the column 'Voice mail plan'

# %% [markdown]
# # crosstab()

# %%
vmplan = pd.crosstab(data['Voice mail plan'], data['Churn'], margins=True)

vmplan
# Out:
# Churn            False  True   All
# Voice mail plan
# No                1610   323  1933
# Yes                668    65   733
# All               2278   388  2666

# %% [markdown]
# # creating a new column

# %%
vmplan['Churn percent'] = vmplan[True]/vmplan['All'] * 100
vmplan

#creating a new column' Churn percent' to show the churn percentage of the customers who were using voice mail plan
# Out:
# Churn            False  True   All  Churn percent
# Voice mail plan
# No                1610   323  1933      16.709778
# Yes                668    65   733       8.867667
# All               2278   388  2666      14.553638

# %%
data['Voice mail plan'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
v=data['Voice mail plan'].value_counts()
v
# Out:
# No     1933
# Yes     733
# Name: Voice mail plan, dtype: int64

# %%
#Creating a donut chart of customer count having voice_mall "plan" and "not having voice mail plan"

plt.pie(v, labels=["No", "Yes"], startangle=90, shadow=True, radius=1.5, explode=(0,0.1), autopct='%1.2f%%')

circle = plt.Circle((0,0),0.8, color='white')
c= plt.gcf()

c.gca().add_artist(circle)
plt.title("Voice Mail Plan DSL")
plt.show()

# %%
# Create a pie chart
plt.pie(v, labels=["No", "Yes"], startangle=90, shadow=True, radius=1.5, explode=(0, 0.1), autopct='%1.2f%%')

# Create a white circle in the center
circle = plt.Circle((0, 0), 0.8, color='white')

# Create a new figure and axis for the circle
fig, ax = plt.subplots()

# Add the circle to the new axis
ax.add_artist(circle)

# Set axis aspect to equal to make it a circle
ax.set_aspect('equal')

# Set a title
plt.title("Voice Mail Plan DSL")

# Show the plot
plt.show()

# %% [markdown]
# # 7. Analyzing the 'Number vmail messages' Column

# %%
data.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
data['Number vmail messages'].unique()
# Out:
# array([25, 26,  0, 24, 37, 27, 33, 39, 41, 28, 30, 34, 46, 35, 21, 42, 36,
#        22, 23, 43, 31, 38, 40, 29, 18, 32, 17, 45, 16, 14, 20, 19, 15, 12,
#        47,  8, 44,  4, 10, 13, 50,  9], dtype=int64)

# %%
data['Number vmail messages'].value_counts().head()
# Out:
# 0     1933
# 31      50
# 28      42
# 29      39
# 24      37
# Name: Number vmail messages, dtype: int64

# %% [markdown]
# # describe()

# %%
data['Number vmail messages'].describe()

# to show the summary statistics of the column. It checks and large deviations etc.
# it shows the count of non-null values, mean, std, minimum, maximum, 25th, 50th, 75th, percentile value.
# Percentile means - how many of the values are less than the given percentile.
# Out:
# count    2666.000000
# mean        8.021755
# std        13.612277
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%        19.000000
# max        50.000000
# Name: Number vmail messages, dtype: float64

# %% [markdown]
# # Distribution Plot

# %%
sns.displot(data['Number vmail messages']);

# from seaborn we are generating a distribution plot for the column 'Number vmail messages'

# %% [markdown]
# # Box Plot

# %%
sns.boxplot (x='Churn', y= 'Number vmail messages', color='violet', meanline=True, showmeans=True, sym='r+',data=data) 
#creating a box plot for the column number vmail messages... grouped by column churn 

plt.figure(figsize =(5, 5)) #Setting the size of the figure as 5x5, using matplotlib Library
plt.show() # to show the box plat

#In box plot, a box is plotted from Ist quartile to IIIrd quartile
#here, in this boxplot... we have values from churn column on x-axis and distribution at y-axis... 
#there are no outliers... the boundaries are at 0 and 51 the minimum value is at 0... 
#the first quartile (25%) is at 0... the second quartile (50%) is also at 0... 
#the third quartile (75th percentile) is at 20... the maximum value is at 51 
# color is set as violet... meanline=True indicates the mean Line ... showmeans=True indicates the mean point... 
#sym-'r+' to change the symbol to + sign with red color... data is taken from our original dataframe 'data'

# %% [markdown]
# # 8. Analyzing the 'Customer service calls' Column

# %%
data.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
data['Customer service calls'].nunique()
# Out:
# 10

# %%
data['Customer service calls'].unique()
# Out:
# array([1, 0, 2, 3, 4, 5, 7, 9, 6, 8], dtype=int64)

# %%
data['Customer service calls'].value_counts()
# Out:
# 1    945
# 2    608
# 0    555
# 3    348
# 4    133
# 5     49
# 6     17
# 7      8
# 9      2
# 8      1
# Name: Customer service calls, dtype: int64

# %%
churn_data = data[data['Churn']]  # creating a new dataframe 'churn_data', with the records of all the churned customers
churn_data
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 18      CO              77        408                 No              No
# 28      AZ              12        408                 No              No
# 35      MD             135        408                Yes             Yes
# 45      WY              87        415                 No              No
# 48      CO             121        408                 No             Yes
# ...    ...             ...        ...                ...             ...
# 2631    MI             119        510                Yes             Yes
# 2641    IL              71        510                Yes              No
# 2656    GA             122        510                Yes              No
# 2657    MD              62        408                 No              No
# 2658    IN             117        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
churn_data['Customer service calls'].value_counts()
# Out:
# 1    99
# 0    79
# 4    64
# 2    62
# 3    37
# 5    29
# 6    10
# 7     5
# 9     2
# 8     1
# Name: Customer service calls, dtype: int64

# %% [markdown]
# # crosstab()

# %%
cscalls = pd.crosstab(data['Customer service calls'], data['Churn'], margins=True)

cscalls['churn percent']=cscalls[True]/cscalls['All']*100

cscalls
# Out:
# Churn                   False  True   All  churn percent
# Customer service calls
# 0                         476    79   555      14.234234
# 1                         846    99   945      10.476190
# 2                         546    62   608      10.197368
# 3                         311    37   348      10.632184
# 4                          69    64   133      48.120301
# 5                          20    29    49      59.183673
# 6                           7    10    17      58.823529
# 7                           3     5     8      62.500000
# 8                           0     1     1     100.000000
# 9                           0     2     2     100.000000
# All                      2278   388  2666      14.553638

# %% [markdown]
# # Countplot

# %%
sns.countplot(x='Customer service calls', hue='Churn', color='brown', data=data)
plt.show()

# %% [markdown]
# # 9. Analyzing the 'Per minute charge'

# %%
data.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %% [markdown]
# # mean()

# %%
dc_pm = data['Total day charge'].mean()/data['Total day minutes'].mean()
# checking per minute day charge
ec_pm = data['Total eve charge'].mean()/data['Total eve minutes'].mean()
# checking per minute evening charge
nc_pm = data['Total night charge'].mean()/data['Total night minutes'].mean()
# checking per minute night charge
intc_pm = data['Total intl charge'].mean()/data['Total intl minutes'].mean()
# checking per minute night charge

# %%
print(dc_pm)  # printing per minute day charge
print(ec_pm)  # printing per minute evening charge
print(nc_pm)  # printing per minute night charge
print(intc_pm)  # printing per minute international charge
# Out:
# 0.17000294672078045
# 0.08500124010373818
# 0.0450004325804693
# 0.27004825607597854

# %% [markdown]
# # Bar plot

# %%
# Bar plot

sns.barplot(x=['day','evening','night','intl'], y=[dc_pm,ec_pm,nc_pm,intc_pm])
plt.show()

# Drawing a bar plot to represent different 'per minute call charges'
# on x-axis we have given the naming .... on y-axis we have given the charges

# %% [markdown]
# # By - Gaurang Dwivedi

# %% [markdown]
# # Thanks !
